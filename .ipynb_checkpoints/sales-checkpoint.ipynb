# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
train=pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
copy=train
copy=copy.drop('Id', axis=1)
copy=copy.drop('SalePrice', axis=1)
column_s = copy.select_dtypes(include = 'number').columns.tolist()

# %%
ID = test['Id']
train_y=train['SalePrice']
train = train.drop('Id', axis=1)

test = test.drop(['Id'], axis = 1)

# %%
pd.set_option('display.max_columns', None) # for showing all columns in pd.head()

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %%
test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave   NaN      Reg
# 1          20       RL         81.0    14267   Pave   NaN      IR1
# 2          60       RL         74.0    13830   Pave   NaN      IR1
# 3          60       RL         78.0     9978   Pave   NaN      IR1
# 4         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# ...

# %% [markdown]
# # Data Visualization

# %%
#from ydata_profiling import ProfileReport
#prof = ProfileReport(train)
#prof.to_file(output_file='output.html')

# %%
#from ydata_profiling import ProfileReport
#prof = ProfileReport(test)
#prof.to_file(output_file='output_test.html')

# %%
plt.figure(figsize = (30, 10))
sns.heatmap(train.isna())
plt.show()

# %%
plt.figure(figsize = (30, 10))
sns.heatmap(test.isna())
plt.show()

# %%
null_columns_train=train.columns[train.isnull().any()].tolist()
null_columns_test=test.columns[test.isnull().any()].tolist()

# %%
un_null_train = list(set(null_columns_train)-set(null_columns_test))
un_null_test = list(set(null_columns_test)-set(null_columns_train))

# %%
un_null_train
# Out:
# ['Electrical']

# %%
un_null_test
# Out:
# ['SaleType',
#  'Exterior2nd',
#  'Utilities',
#  'Functional',
#  'Exterior1st',
#  'BsmtFullBath',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'KitchenQual',
#  'GarageArea',
#  'MSZoning',
#  'BsmtUnfSF',
#  'BsmtHalfBath',
#  'TotalBsmtSF',
#  'GarageCars']

# %%
null_columns_train
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %% [markdown]
# # Handling Missing Values

# %%
train['Alley']= train['Alley'].fillna('M')
test['Alley']= train['Alley'].fillna('M')
train.loc[train['MasVnrType'].isna()& (train['MasVnrArea']==0), 'MasVnrType'] = 'M'
test.loc[test['MasVnrType'].isna()& (test['MasVnrArea']==0), 'MasVnrType'] = 'M'
train['BsmtQual']= train['BsmtQual'].fillna('M')
test['BsmtQual']= test['BsmtQual'].fillna('M')
train['BsmtCond']= train['BsmtCond'].fillna('M')
test['BsmtCond']= test['BsmtCond'].fillna('M')
train.loc[train['BsmtExposure'].isna() & (train['BsmtQual']=='M'), 'BsmtExposure']='M'
test.loc[test['BsmtExposure'].isna() & (test['BsmtQual']=='M'), 'BsmtExposure']='M'
train.loc[train['BsmtFinType1'].isna() & (train['BsmtQual']=='M'), 'BsmtFinType1']='M'
test.loc[test['BsmtFinType1'].isna() & (test['BsmtQual']=='M'), 'BsmtFinType1']='M'
train['BsmtFinType2']=train['BsmtFinType2'].fillna('M')
test['BsmtFinType2']=test['BsmtFinType2'].fillna('M')
train['Electrical']=train['Electrical'].fillna('SBrkr')

train['FireplaceQu']=train['FireplaceQu'].fillna('M')
test['FireplaceQu']=test['FireplaceQu'].fillna('M')
train['GarageType']=train['GarageType'].fillna('M')
test['GarageType']=test['GarageType'].fillna('M')

train['GarageFinish']=train['GarageFinish'].fillna('M')
test['GarageFinish']=test['GarageFinish'].fillna('M')
train['GarageCond']=train['GarageCond'].fillna('M')
test['GarageCond']=test['GarageCond'].fillna('M')
train['GarageQual']=train['GarageQual'].fillna('M')
test['GarageQual']=test['GarageQual'].fillna('M')
train['PoolQC'] = train['PoolQC'].fillna('M')
test['PoolQC'] = test['PoolQC'].fillna('M')
train['Fence']=train['Fence'].fillna('M')
test['Fence']=test['Fence'].fillna('M')
train['MiscFeature']=train['MiscFeature'].fillna('M')
test['MiscFeature']=test['MiscFeature'].fillna('M')

# %%
train['GarageYrBlt']=train['GarageYrBlt'].fillna(0)
test['GarageYrBlt']=test['GarageYrBlt'].fillna(0)

# %%
test['Utilities']=test['Utilities'].fillna('AllPub')
test['KitchenQual']=test['KitchenQual'].fillna('TA')
test['MSZoning']=test['MSZoning'].fillna('RL')
test['Exterior1st']=test['Exterior1st'].fillna('VinylSd')
test['Exterior2nd']=test['Exterior2nd'].fillna('VinylSd')
test['BsmtFinSF1']=test['BsmtFinSF1'].fillna(0)
test['BsmtFinSF2']=test['BsmtFinSF2'].fillna(0)
test['BsmtUnfSF']=test['BsmtUnfSF'].fillna(0)
test['TotalBsmtSF']=test['TotalBsmtSF'].fillna(0)
test['BsmtFullBath']=test['BsmtFullBath'].fillna(0)
test['BsmtHalfBath']=test['BsmtHalfBath'].fillna(0)
test['Functional']=test['Functional'].fillna('Typ')
test['GarageCars']=test['GarageCars'].fillna(2)
test['GarageArea']=test['GarageArea'].fillna(473)
test['SaleType']=test['SaleType'].fillna('WD')

# %% [markdown]
# #### Alley

# %%
grp = train.groupby('Alley')['SalePrice'].sum()
grp=grp.reset_index()
grp=grp.sort_values('Alley')

# %%
grp.head()
# Out:
#   Alley  SalePrice
# 0  Grvl    6110954
# 1     M  251145968
# 2  Pave    6888024

# %%
n=train['Alley'].value_counts().reset_index()
n.columns=['Alley', 'count']
n=n.sort_values('Alley')

# %%
n.head()
# Out:
#   Alley  count
# 1  Grvl     50
# 0     M   1369
# 2  Pave     41

# %%
grp = grp.merge(n, on="Alley")

# %%
grp.head()
# Out:
#   Alley  SalePrice  count
# 0  Grvl    6110954     50
# 1     M  251145968   1369
# 2  Pave    6888024     41

# %%
grp['Avg']=(grp['SalePrice']/grp['count'])

# %%
grp.head()
# Out:
#   Alley  SalePrice  count            Avg
# 0  Grvl    6110954     50  122219.080000
# 1     M  251145968   1369  183452.131483
# 2  Pave    6888024     41  168000.585366

# %%
sns.barplot(x=grp['Alley'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Alley', ylabel='Avg'>

# %%
train['Alley']=train['Alley'].map({'Grvl':1, 'Pave':2, 'M':3})
test['Alley']=test['Alley'].map({'Grvl':1, 'Pave':2, 'M':3})

# %%
train['Alley'].value_counts()
# Out:
# Alley
# 3    1369
# 1      50
# 2      41
# Name: count, dtype: int64

# %% [markdown]
# #### MasVnrType

# %%
grp=train.groupby('MasVnrType')['SalePrice'].sum().reset_index()

# %%
grp=grp.sort_values('MasVnrType')
n=train['MasVnrType'].value_counts().reset_index()
n.columns= ['MasVnrType', 'count']
n=n.sort_values('MasVnrType')

# %%
grp.head()
# Out:
#   MasVnrType  SalePrice
# 0     BrkCmn    2194771
# 1    BrkFace   91087883
# 2          M  134156064
# 3      Stone   33994704

# %%
n.head()
# Out:
#   MasVnrType  count
# 3     BrkCmn     15
# 1    BrkFace    445
# 0          M    859
# 2      Stone    128

# %%
grp =grp.merge(n, on='MasVnrType')
grp.head()
# Out:
#   MasVnrType  SalePrice  count
# 0     BrkCmn    2194771     15
# 1    BrkFace   91087883    445
# 2          M  134156064    859
# 3      Stone   33994704    128

# %%
grp['Avg']=grp['SalePrice']/grp['count']
grp.head()
# Out:
#   MasVnrType  SalePrice  count            Avg
# 0     BrkCmn    2194771     15  146318.066667
# 1    BrkFace   91087883    445  204691.871910
# 2          M  134156064    859  156177.024447
# 3      Stone   33994704    128  265583.625000

# %%
sns.barplot(x=grp['MasVnrType'], y=grp['Avg'])
# Out:
# <Axes: xlabel='MasVnrType', ylabel='Avg'>

# %%
train['MasVnrType']=train['MasVnrType'].map({'BrkCmn':1, 'M':2, 'BrkFace':3, 'Stone':4})
test['MasVnrType']=test['MasVnrType'].map({'BrkCmn':1, 'M':2, 'BrkFace':3, 'Stone':4})

# %% [markdown]
# #### BsmtQual

# %%
grp=train.groupby('BsmtQual')['SalePrice'].sum().reset_index()
grp=grp.sort_values('BsmtQual')
n=train['BsmtQual'].value_counts().reset_index()
n.columns= ['BsmtQual', 'count']
n=n.sort_values('BsmtQual')
grp =grp.merge(n, on='BsmtQual')
grp.head()
# Out:
#   BsmtQual  SalePrice  count
# 0       Ex   39571966    121
# 1       Fa    4049221     35
# 2       Gd  125261480    618
# 3        M    3909157     37
# 4       TA   91353122    649

# %%
grp['Avg']=grp['SalePrice']/grp['count']
sns.barplot(x=grp['BsmtQual'], y=grp['Avg'])
# Out:
# <Axes: xlabel='BsmtQual', ylabel='Avg'>

# %%
train['BsmtQual']=train['BsmtQual'].map({'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test['BsmtQual']=test['BsmtQual'].map({'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})

# %% [markdown]
# #### BsmtCond

# %%
grp=train.groupby('BsmtCond')['SalePrice'].sum().reset_index()
grp=grp.sort_values('BsmtCond')
n=train['BsmtCond'].value_counts().reset_index()
n.columns= ['BsmtCond', 'count']
n=n.sort_values('BsmtCond')
grp =grp.merge(n, on='BsmtCond')
grp.head()
# Out:
#   BsmtCond  SalePrice  count
# 0       Fa    5481429     45
# 1       Gd   13883994     65
# 2        M    3909157     37
# 3       Po     128000      2
# 4       TA  240742366   1311

# %%
grp['Avg']=grp['SalePrice']/grp['count']
sns.barplot(x=grp['BsmtCond'], y=grp['Avg'])
# Out:
# <Axes: xlabel='BsmtCond', ylabel='Avg'>

# %%
train['BsmtCond']=train['BsmtCond'].map({'Po':1, 'M':2, 'Fa':3, 'TA':4, 'Gd':5})
test['BsmtCond']=test['BsmtCond'].map({'Po':1, 'M':2, 'Fa':3, 'TA':4, 'Gd':5})

# %% [markdown]
# #### BsmtExposure

# %%
grp=train.groupby('BsmtExposure')['SalePrice'].sum().reset_index()
grp=grp.sort_values('BsmtExposure')
n=train['BsmtExposure'].value_counts().reset_index()
n.columns= ['BsmtExposure', 'count']
n=n.sort_values('BsmtExposure')
grp =grp.merge(n, on='BsmtExposure')
grp.head()
# Out:
#   BsmtExposure  SalePrice  count
# 0           Av   45668196    221
# 1           Gd   34530434    134
# 2            M    3909157     37
# 3           Mn   21978021    114
# 4           No  157866638    953

# %%
grp['Avg']=grp['SalePrice']/grp['count']
sns.barplot(x=grp['BsmtExposure'], y=grp['Avg'])
# Out:
# <Axes: xlabel='BsmtExposure', ylabel='Avg'>

# %%
train['BsmtExposure']=train['BsmtExposure'].map({'M':1, 'No':2, 'Mn':3, 'Av':4, 'Gd':5})
test['BsmtExposure']=test['BsmtExposure'].map({'M':1, 'No':2, 'Mn':3, 'Av':4, 'Gd':5})

# %% [markdown]
# #### BsmtFinType1

# %%
grp=train.groupby('BsmtFinType1')['SalePrice'].sum().reset_index()
grp=grp.sort_values('BsmtFinType1')
n=train['BsmtFinType1'].value_counts().reset_index()
n.columns= ['BsmtFinType1', 'count']
n=n.sort_values('BsmtFinType1')
grp =grp.merge(n, on='BsmtFinType1')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['BsmtFinType1'], y=grp['Avg'])
# Out:
# <Axes: xlabel='BsmtFinType1', ylabel='Avg'>

# %%
train['BsmtFinType1']=train['BsmtFinType1'].map({'M':1, 'Rec':2, 'BLQ':3, 'LwQ':4, 'ALQ':5, 'Unf':6, 'GLQ':7})
test['BsmtFinType1']=test['BsmtFinType1'].map({'M':1, 'Rec':2, 'BLQ':3, 'LwQ':4, 'ALQ':5, 'Unf':6, 'GLQ':7})

# %% [markdown]
# #### BsmtFinType2

# %%
grp=train.groupby('BsmtFinType2')['SalePrice'].sum().reset_index()
grp=grp.sort_values('BsmtFinType2')
n=train['BsmtFinType2'].value_counts().reset_index()
n.columns= ['BsmtFinType2', 'count']
n=n.sort_values('BsmtFinType2')
grp =grp.merge(n, on='BsmtFinType2')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['BsmtFinType2'], y=grp['Avg'])
# Out:
# <Axes: xlabel='BsmtFinType2', ylabel='Avg'>

# %%
train['BsmtFinType2']= train['BsmtFinType2'].map({'M':1, 'BLQ':2, 'LwQ':3, 'Rec':4, 'GLQ':5, 'Unf':6, 'ALQ':7})
test['BsmtFinType2']= test['BsmtFinType2'].map({'M':1, 'BLQ':2, 'LwQ':3, 'Rec':4, 'GLQ':5, 'Unf':6, 'ALQ':7})

# %% [markdown]
# #### Electrical

# %%
grp=train.groupby('Electrical')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Electrical')
n=train['Electrical'].value_counts().reset_index()
n.columns= ['Electrical', 'count']
n=n.sort_values('Electrical')
grp =grp.merge(n, on='Electrical')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Electrical'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Electrical', ylabel='Avg'>

# %%
train['Electrical']=train['Electrical'].map({'Mix':1, 'FuseP':2, 'FuseF':3, 'FuseA':4, 'SBrkr':5})
test['Electrical']=test['Electrical'].map({'Mix':1, 'FuseP':2, 'FuseF':3, 'FuseA':4, 'SBrkr':5})

# %% [markdown]
# #### FireplaceQu

# %%
grp=train.groupby('FireplaceQu')['SalePrice'].sum().reset_index()
grp=grp.sort_values('FireplaceQu')
n=train['FireplaceQu'].value_counts().reset_index()
n.columns= ['FireplaceQu', 'count']
n=n.sort_values('FireplaceQu')
grp =grp.merge(n, on='FireplaceQu')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['FireplaceQu'], y=grp['Avg'])
# Out:
# <Axes: xlabel='FireplaceQu', ylabel='Avg'>

# %%
train['FireplaceQu']=train['FireplaceQu'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test['FireplaceQu']=test['FireplaceQu'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})

# %% [markdown]
# #### GarageType

# %%
grp=train.groupby('GarageType')['SalePrice'].sum().reset_index()
grp=grp.sort_values('GarageType')
n=train['GarageType'].value_counts().reset_index()
n.columns= ['GarageType', 'count']
n=n.sort_values('GarageType')
grp =grp.merge(n, on='GarageType')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['GarageType'], y=grp['Avg'])
# Out:
# <Axes: xlabel='GarageType', ylabel='Avg'>

# %%
train['GarageType']=train['GarageType'].map({'M':1, 'CarPort':2, 'Detchd':3, '2Types':4, 'Basment':5, 'Attchd':6, 'BuiltIn':7})
test['GarageType']=test['GarageType'].map({'M':1, 'CarPort':2, 'Detchd':3, '2Types':4, 'Basment':5, 'Attchd':6, 'BuiltIn':7})

# %% [markdown]
# #### GarageFinish

# %%
grp=train.groupby('GarageFinish')['SalePrice'].sum().reset_index()
grp=grp.sort_values('GarageFinish')
n=train['GarageFinish'].value_counts().reset_index()
n.columns= ['GarageFinish', 'count']
n=n.sort_values('GarageFinish')
grp =grp.merge(n, on='GarageFinish')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['GarageFinish'], y=grp['Avg'])
# Out:
# <Axes: xlabel='GarageFinish', ylabel='Avg'>

# %%
train['GarageFinish']=train['GarageFinish'].map({'M':1, 'Unf':2, 'RFn':3, 'Fin':4})
test['GarageFinish']=test['GarageFinish'].map({'M':1, 'Unf':2, 'RFn':3, 'Fin':4})

# %% [markdown]
# #### GarageQual

# %%
grp=train.groupby('GarageQual')['SalePrice'].sum().reset_index()
grp=grp.sort_values('GarageQual')
n=train['GarageQual'].value_counts().reset_index()
n.columns= ['GarageQual', 'count']
n=n.sort_values('GarageQual')
grp =grp.merge(n, on='GarageQual')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['GarageQual'], y=grp['Avg'])
# Out:
# <Axes: xlabel='GarageQual', ylabel='Avg'>

# %%
train['GarageQual']=train['GarageQual'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test['GarageQual']=test['GarageQual'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})

# %% [markdown]
# #### GarageCond

# %%
grp=train.groupby('GarageCond')['SalePrice'].sum().reset_index()
grp=grp.sort_values('GarageCond')
n=train['GarageCond'].value_counts().reset_index()
n.columns= ['GarageCond', 'count']
n=n.sort_values('GarageCond')
grp =grp.merge(n, on='GarageCond')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['GarageCond'], y=grp['Avg'])
# Out:
# <Axes: xlabel='GarageCond', ylabel='Avg'>

# %%
train['GarageCond']=train['GarageCond'].map({'M':1, 'Po':2, 'Fa':3, 'Ex':4, 'Gd':5, 'TA':6})
test['GarageCond']=test['GarageCond'].map({'M':1, 'Po':2, 'Fa':3, 'Ex':4, 'Gd':5, 'TA':6})

# %% [markdown]
# #### PoolQC

# %%
grp=train.groupby('PoolQC')['SalePrice'].sum().reset_index()
grp=grp.sort_values('PoolQC')
n=train['PoolQC'].value_counts().reset_index()
n.columns= ['PoolQC', 'count']
n=n.sort_values('PoolQC')
grp =grp.merge(n, on='PoolQC')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['PoolQC'], y=grp['Avg'])
# Out:
# <Axes: xlabel='PoolQC', ylabel='Avg'>

# %%
train['PoolQC']=train['PoolQC'].map({'M':1, 'Gd':2, 'Fa':3, 'Ex':4})
test['PoolQC']=test['PoolQC'].map({'M':1, 'Gd':2, 'Fa':3, 'Ex':4})

# %% [markdown]
# #### Fence

# %%
grp=train.groupby('Fence')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Fence')
n=train['Fence'].value_counts().reset_index()
n.columns= ['Fence', 'count']
n=n.sort_values('Fence')
grp =grp.merge(n, on='Fence')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Fence'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Fence', ylabel='Avg'>

# %%
train['Fence']=train['Fence'].map({'MnWw':1, 'GdWo':2, 'MnPrv':3, 'GdPrv':4, 'M':5})
test['Fence']=test['Fence'].map({'MnWw':1, 'GdWo':2, 'MnPrv':3, 'GdPrv':4, 'M':5})

# %% [markdown]
# #### MiscFeature

# %%
grp=train.groupby('MiscFeature')['SalePrice'].sum().reset_index()
grp=grp.sort_values('MiscFeature')
n=train['MiscFeature'].value_counts().reset_index()
n.columns= ['MiscFeature', 'count']
n=n.sort_values('MiscFeature')
grp =grp.merge(n, on='MiscFeature')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['MiscFeature'], y=grp['Avg'])
# Out:
# <Axes: xlabel='MiscFeature', ylabel='Avg'>

# %%
train['MiscFeature']=train['MiscFeature'].map({'Othr':1, 'Shed':2, 'Gar2':3, 'M':4, 'TenC':5})
test['MiscFeature']=test['MiscFeature'].map({'Othr':1, 'Shed':2, 'Gar2':3, 'M':4, 'TenC':5})

# %% [markdown]
# # Encoding

# %% [markdown]
# #### MSZoning

# %%
grp=train.groupby('MSZoning')['SalePrice'].sum().reset_index()
grp=grp.sort_values('MSZoning')
n=train['MSZoning'].value_counts().reset_index()
n.columns= ['MSZoning', 'count']
n=n.sort_values('MSZoning')
grp =grp.merge(n, on='MSZoning')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['MSZoning'], y=grp['Avg'])
# Out:
# <Axes: xlabel='MSZoning', ylabel='Avg'>

# %%
train['MSZoning']=train['MSZoning'].map({'C (all)':1, 'RM':2, 'RH':3, 'RL':4, 'FV':5})
test['MSZoning']=test['MSZoning'].map({'C (all)':1, 'RM':2, 'RH':3, 'RL':4, 'FV':5})

# %% [markdown]
# #### Street

# %%
grp=train.groupby('Street')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Street')
n=train['Street'].value_counts().reset_index()
n.columns= ['Street', 'count']
n=n.sort_values('Street')
grp =grp.merge(n, on='Street')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Street'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Street', ylabel='Avg'>

# %%
train['Street']=train['Street'].map({'Grvl':1, 'Pave':2})
test['Street']=test['Street'].map({'Grvl':1, 'Pave':2})

# %% [markdown]
# #### LotShape

# %%
grp=train.groupby('LotShape')['SalePrice'].sum().reset_index()
grp=grp.sort_values('LotShape')
n=train['LotShape'].value_counts().reset_index()
n.columns= ['LotShape', 'count']
n=n.sort_values('LotShape')
grp =grp.merge(n, on='LotShape')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['LotShape'], y=grp['Avg'])
# Out:
# <Axes: xlabel='LotShape', ylabel='Avg'>

# %%
train['LotShape']=train['LotShape'].map({'Reg':1, 'IR1':2, 'IR3':3, 'IR2':4})
test['LotShape']=test['LotShape'].map({'Reg':1, 'IR1':2, 'IR3':3, 'IR2':4})

# %% [markdown]
# #### LandContour

# %%
grp=train.groupby('LandContour')['SalePrice'].sum().reset_index()
grp=grp.sort_values('LandContour')
n=train['LandContour'].value_counts().reset_index()
n.columns= ['LandContour', 'count']
n=n.sort_values('LandContour')
grp =grp.merge(n, on='LandContour')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['LandContour'], y=grp['Avg'])
# Out:
# <Axes: xlabel='LandContour', ylabel='Avg'>

# %%
train['LandContour']=train['LandContour'].map({'Bnk':1, 'Lvl':2, 'Low':3, 'HLS':4})
test['LandContour']=test['LandContour'].map({'Bnk':1, 'Lvl':2, 'Low':3, 'HLS':4})

# %% [markdown]
# #### Utilities

# %%
grp=train.groupby('Utilities')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Utilities')
n=train['Utilities'].value_counts().reset_index()
n.columns= ['Utilities', 'count']
n=n.sort_values('Utilities')
grp =grp.merge(n, on='Utilities')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Utilities'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Utilities', ylabel='Avg'>

# %%
train['Utilities']=train['Utilities'].map({'NoSeWa':1, 'AllPub':2})
test['Utilities']=test['Utilities'].map({'NoSeWa':1, 'AllPub':2})

# %% [markdown]
# #### LotConfig

# %%
grp=train.groupby('LotConfig')['SalePrice'].sum().reset_index()
grp=grp.sort_values('LotConfig')
n=train['LotConfig'].value_counts().reset_index()
n.columns= ['LotConfig', 'count']
n=n.sort_values('LotConfig')
grp =grp.merge(n, on='LotConfig')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['LotConfig'], y=grp['Avg'])
# Out:
# <Axes: xlabel='LotConfig', ylabel='Avg'>

# %%
train['LotConfig']=train['LotConfig'].map({'Inside':1, 'FR2':2, 'Corner':3, 'FR3':4, 'CulDSac':5})
test['LotConfig']=test['LotConfig'].map({'Inside':1, 'FR2':2, 'Corner':3, 'FR3':4, 'CulDSac':5})

# %% [markdown]
# #### LandSlope

# %%
grp=train.groupby('LandSlope')['SalePrice'].sum().reset_index()
grp=grp.sort_values('LandSlope')
n=train['LandSlope'].value_counts().reset_index()
n.columns= ['LandSlope', 'count']
n=n.sort_values('LandSlope')
grp =grp.merge(n, on='LandSlope')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['LandSlope'], y=grp['Avg'])
# Out:
# <Axes: xlabel='LandSlope', ylabel='Avg'>

# %%
train['LandSlope']=train['LandSlope'].map({'Gtl':1, 'Mod':2, 'Sev':3})
test['LandSlope']=test['LandSlope'].map({'Gtl':1, 'Mod':2, 'Sev':3})

# %% [markdown]
# #### Neighborhood

# %%
grp=train.groupby('Neighborhood')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Neighborhood')
n=train['Neighborhood'].value_counts().reset_index()
n.columns= ['Neighborhood', 'count']
n=n.sort_values('Neighborhood')
grp =grp.merge(n, on='Neighborhood')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')

# %%
plt.figure(figsize=(30, 30))
sns.barplot(x=grp['Neighborhood'], y=grp['Avg'])
plt.show()

# %%
train['Neighborhood']=train['Neighborhood'].map({'MeadowV':1, 'IDOTRR':2, 'BrDale':3, 'BrkSide':4, 'Edwards':5, 'OldTown':6, 'Sawyer':7, 'Blueste':8, 'SWISU':9, 'NPkVill':10, 'NAmes':11, 'Mitchel':12, 'SawyerW':13, 'NWAmes':14, 'Gilbert':15, 'Blmngtn':16, 'CollgCr':17, 'Crawfor':18, 'ClearCr':19, 'Somerst':20, 'Veenker':21, 'Timber':22, 'StoneBr':23, 'NridgHt':24, 'NoRidge':25}) 
test['Neighborhood']=test['Neighborhood'].map({'MeadowV':1, 'IDOTRR':2, 'BrDale':3, 'BrkSide':4, 'Edwards':5, 'OldTown':6, 'Sawyer':7, 'Blueste':8, 'SWISU':9, 'NPkVill':10, 'NAmes':11, 'Mitchel':12, 'SawyerW':13, 'NWAmes':14, 'Gilbert':15, 'Blmngtn':16, 'CollgCr':17, 'Crawfor':18, 'ClearCr':19, 'Somerst':20, 'Veenker':21, 'Timber':22, 'StoneBr':23, 'NridgHt':24, 'NoRidge':25})

# %% [markdown]
# #### Condition1

# %%
grp=train.groupby('Condition1')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Condition1')
n=train['Condition1'].value_counts().reset_index()
n.columns= ['Condition1', 'count']
n=n.sort_values('Condition1')
grp =grp.merge(n, on='Condition1')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Condition1'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Condition1', ylabel='Avg'>

# %%
train['Condition1']=train['Condition1'].map({'Artery':1, 'RRAe':2, 'Feedr':3, 'RRAn':4, 'Norm':5, 'RRNe':6, 'RRNn':7, 'PosN':8, 'PosA':9})
test['Condition1']=test['Condition1'].map({'Artery':1, 'RRAe':2, 'Feedr':3, 'RRAn':4, 'Norm':5, 'RRNe':6, 'RRNn':7, 'PosN':8, 'PosA':9})

# %% [markdown]
# #### Condition2

# %%
grp=train.groupby('Condition2')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Condition2')
n=train['Condition2'].value_counts().reset_index()
n.columns= ['Condition2', 'count']
n=n.sort_values('Condition2')
grp =grp.merge(n, on='Condition2')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Condition2'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Condition2', ylabel='Avg'>

# %%
train['Condition2']=train['Condition2'].map({'RRNn':1, 'Artery':2, 'Feedr':3, 'RRAn':4, 'Norm':5, 'RRAe':6, 'PosN':7, 'PosA':8})
test['Condition2']=test['Condition2'].map({'RRNn':1, 'Artery':2, 'Feedr':3, 'RRAn':4, 'Norm':5, 'RRAe':6, 'PosN':7, 'PosA':8})

# %% [markdown]
# #### BldgType

# %%
grp=train.groupby('BldgType')['SalePrice'].sum().reset_index()
grp=grp.sort_values('BldgType')
n=train['BldgType'].value_counts().reset_index()
n.columns= ['BldgType', 'count']
n=n.sort_values('BldgType')
grp =grp.merge(n, on='BldgType')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['BldgType'], y=grp['Avg'])
# Out:
# <Axes: xlabel='BldgType', ylabel='Avg'>

# %%
train['BldgType']=train['BldgType'].map({'2fmCon':1, 'Duplex':2, 'Twnhs':3, 'TwnhsE':4, '1Fam':5})
test['BldgType']=test['BldgType'].map({'2fmCon':1, 'Duplex':2, 'Twnhs':3, 'TwnhsE':4, '1Fam':5})

# %% [markdown]
# #### HouseStyle

# %%
grp=train.groupby('HouseStyle')['SalePrice'].sum().reset_index()
grp=grp.sort_values('HouseStyle')
n=train['HouseStyle'].value_counts().reset_index()
n.columns= ['HouseStyle', 'count']
n=n.sort_values('HouseStyle')
grp =grp.merge(n, on='HouseStyle')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['HouseStyle'], y=grp['Avg'])
# Out:
# <Axes: xlabel='HouseStyle', ylabel='Avg'>

# %%
train['HouseStyle']=train['HouseStyle'].map({'1.5Unf':1, 'SFoyer':2, '1.5Fin':3, '2.5Unf':4, 'SLvl':5, '1Story':6, '2Story':7, '2.5Fin':8})
test['HouseStyle']=test['HouseStyle'].map({'1.5Unf':1, 'SFoyer':2, '1.5Fin':3, '2.5Unf':4, 'SLvl':5, '1Story':6, '2Story':7, '2.5Fin':8})

# %% [markdown]
# #### RoofStyle

# %%
grp=train.groupby('RoofStyle')['SalePrice'].sum().reset_index()
grp=grp.sort_values('RoofStyle')
n=train['RoofStyle'].value_counts().reset_index()
n.columns= ['RoofStyle', 'count']
n=n.sort_values('RoofStyle')
grp =grp.merge(n, on='RoofStyle')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['RoofStyle'], y=grp['Avg'])
# Out:
# <Axes: xlabel='RoofStyle', ylabel='Avg'>

# %%
train['RoofStyle']=train['RoofStyle'].map({'Gambrel':1, 'Gable':2, 'Mansard':3, 'Flat':4, 'Hip':5, 'Shed':6})
test['RoofStyle']=test['RoofStyle'].map({'Gambrel':1, 'Gable':2, 'Mansard':3, 'Flat':4, 'Hip':5, 'Shed':6})

# %% [markdown]
# #### RoofMatl

# %%
grp=train.groupby('RoofMatl')['SalePrice'].sum().reset_index()
grp=grp.sort_values('RoofMatl')
n=train['RoofMatl'].value_counts().reset_index()
n.columns= ['RoofMatl', 'count']
n=n.sort_values('RoofMatl')
grp =grp.merge(n, on='RoofMatl')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['RoofMatl'], y=grp['Avg'])
# Out:
# <Axes: xlabel='RoofMatl', ylabel='Avg'>

# %%
train['RoofMatl']=train['RoofMatl'].map({'Roll':1, 'ClyTile':2, 'CompShg':3, 'Metal':4, 'Tar&Grv':5, 'WdShake':6, 'Membran':7, 'WdShngl':8})
test['RoofMatl']=test['RoofMatl'].map({'Roll':1, 'ClyTile':2, 'CompShg':3, 'Metal':4, 'Tar&Grv':5, 'WdShake':6, 'Membran':7, 'WdShngl':8})

# %% [markdown]
# #### Exterior1st

# %%
grp=train.groupby('Exterior1st')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Exterior1st')
n=train['Exterior1st'].value_counts().reset_index()
n.columns= ['Exterior1st', 'count']
n=n.sort_values('Exterior1st')
grp =grp.merge(n, on='Exterior1st')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')

# %%
plt.figure(figsize=(30, 10))
sns.barplot(x=grp['Exterior1st'], y=grp['Avg'])
plt.show()

# %%
train['Exterior1st']=train['Exterior1st'].map({'BrkComm':1, 'AsphShn':2, 'CBlock':3, 'AsbShng':4, 'MetalSd':5, 'Wd Sdng':6, 'WdShing':7, 'Stucco':8, 'HdBoard':9, 'Plywood':10, 'BrkFace':11, 'VinylSd':12, 'CemntBd':13, 'Stone':14, 'ImStucc':15})
test['Exterior1st']=test['Exterior1st'].map({'BrkComm':1, 'AsphShn':2, 'CBlock':3, 'AsbShng':4, 'MetalSd':5, 'Wd Sdng':6, 'WdShing':7, 'Stucco':8, 'HdBoard':9, 'Plywood':10, 'BrkFace':11, 'VinylSd':12, 'CemntBd':13, 'Stone':14, 'ImStucc':15})

# %% [markdown]
# #### Exterior2nd

# %%
grp=train.groupby('Exterior2nd')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Exterior2nd')
n=train['Exterior2nd'].value_counts().reset_index()
n.columns= ['Exterior2nd', 'count']
n=n.sort_values('Exterior2nd')
grp =grp.merge(n, on='Exterior2nd')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')

# %%
plt.figure(figsize=(30, 10))
sns.barplot(x=grp['Exterior2nd'], y=grp['Avg'])
plt.show()

# %%
train['Exterior2nd']=train['Exterior2nd'].map({'CBlock':1, 'AsbShng':2, 'Brk Cmn':3, 'AsphShn':4, 'Wd Sdng':5, 'MetalSd':6, 'Stucco':7, 'Stone':8, 'Wd Shng':9, 'HdBoard':10, 'Plywood':11, 'BrkFace':12, 'VinylSd':13, 'CmentBd':14, 'ImStucc':15, 'Other':16})
test['Exterior2nd']=test['Exterior2nd'].map({'CBlock':1, 'AsbShng':2, 'Brk Cmn':3, 'AsphShn':4, 'Wd Sdng':5, 'MetalSd':6, 'Stucco':7, 'Stone':8, 'Wd Shng':9, 'HdBoard':10, 'Plywood':11, 'BrkFace':12, 'VinylSd':13, 'CmentBd':14, 'ImStucc':15, 'Other':16})

# %% [markdown]
# #### ExterQual

# %%
grp=train.groupby('ExterQual')['SalePrice'].sum().reset_index()
grp=grp.sort_values('ExterQual')
n=train['ExterQual'].value_counts().reset_index()
n.columns= ['ExterQual', 'count']
n=n.sort_values('ExterQual')
grp =grp.merge(n, on='ExterQual')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')

# %%
sns.barplot(x=grp['ExterQual'], y=grp['Avg'])
# Out:
# <Axes: xlabel='ExterQual', ylabel='Avg'>

# %%
train['ExterQual']=train['ExterQual'].map({'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test['ExterQual']=test['ExterQual'].map({'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})

# %% [markdown]
# #### ExterCond

# %%
grp=train.groupby('ExterCond')['SalePrice'].sum().reset_index()
grp=grp.sort_values('ExterCond')
n=train['ExterCond'].value_counts().reset_index()
n.columns= ['ExterCond', 'count']
n=n.sort_values('ExterCond')
grp =grp.merge(n, on='ExterCond')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['ExterCond'], y=grp['Avg'])
# Out:
# <Axes: xlabel='ExterCond', ylabel='Avg'>

# %%
train['ExterCond']=train['ExterCond'].map({'Po':1, 'Fa':3, 'Gd':4, 'TA':5, 'Ex':6}) 
test['ExterCond']=test['ExterCond'].map({'Po':1, 'Fa':3, 'Gd':4, 'TA':5, 'Ex':6})

# %% [markdown]
# #### Foundation

# %%
grp=train.groupby('Foundation')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Foundation')
n=train['Foundation'].value_counts().reset_index()
n.columns= ['Foundation', 'count']
n=n.sort_values('Foundation')
grp =grp.merge(n, on='Foundation')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Foundation'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Foundation', ylabel='Avg'>

# %%
train['Foundation']=train['Foundation'].map({'Slab':1, 'BrkTil':2, 'CBlock':3, 'Stone':4, 'Wood':5, 'PConc':6})
test['Foundation']=test['Foundation'].map({'Slab':1, 'BrkTil':2, 'CBlock':3, 'Stone':4, 'Wood':5, 'PConc':6})

# %% [markdown]
# #### Heating

# %%
grp=train.groupby('Heating')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Heating')
n=train['Heating'].value_counts().reset_index()
n.columns= ['Heating', 'count']
n=n.sort_values('Heating')
grp =grp.merge(n, on='Heating')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Heating'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Heating', ylabel='Avg'>

# %%
train['Heating']=train['Heating'].map({'Floor':1, 'Grav':2, 'Wall':3, 'OthW':4, 'GasW':5, 'GasA':6})
test['Heating']=test['Heating'].map({'Floor':1, 'Grav':2, 'Wall':3, 'OthW':4, 'GasW':5, 'GasA':6})

# %% [markdown]
# #### HeatingQC

# %%
grp=train.groupby('HeatingQC')['SalePrice'].sum().reset_index()
grp=grp.sort_values('HeatingQC')
n=train['HeatingQC'].value_counts().reset_index()
n.columns= ['HeatingQC', 'count']
n=n.sort_values('HeatingQC')
grp =grp.merge(n, on='HeatingQC')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['HeatingQC'], y=grp['Avg'])
# Out:
# <Axes: xlabel='HeatingQC', ylabel='Avg'>

# %%
train['HeatingQC']=train['HeatingQC'].map({'Po':1, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6}) 
test['HeatingQC']=test['HeatingQC'].map({'Po':1, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})

# %% [markdown]
# #### CentralAir

# %%
grp=train.groupby('CentralAir')['SalePrice'].sum().reset_index()
grp=grp.sort_values('CentralAir')
n=train['CentralAir'].value_counts().reset_index()
n.columns= ['CentralAir', 'count']
n=n.sort_values('CentralAir')
grp =grp.merge(n, on='CentralAir')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['CentralAir'], y=grp['Avg'])
# Out:
# <Axes: xlabel='CentralAir', ylabel='Avg'>

# %% [markdown]
# That would be one hot encoding

# %% [markdown]
# #### KitchenQual

# %%
grp=train.groupby('KitchenQual')['SalePrice'].sum().reset_index()
grp=grp.sort_values('KitchenQual')
n=train['KitchenQual'].value_counts().reset_index()
n.columns= ['KitchenQual', 'count']
n=n.sort_values('KitchenQual')
grp =grp.merge(n, on='KitchenQual')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['KitchenQual'], y=grp['Avg'])
# Out:
# <Axes: xlabel='KitchenQual', ylabel='Avg'>

# %%
train['KitchenQual']=train['KitchenQual'].map({'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test['KitchenQual']=test['KitchenQual'].map({'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})

# %% [markdown]
# #### Functional

# %%
grp=train.groupby('Functional')['SalePrice'].sum().reset_index()
grp=grp.sort_values('Functional')
n=train['Functional'].value_counts().reset_index()
n.columns= ['Functional', 'count']
n=n.sort_values('Functional')
grp =grp.merge(n, on='Functional')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['Functional'], y=grp['Avg'])
# Out:
# <Axes: xlabel='Functional', ylabel='Avg'>

# %%
train['Functional']=train['Functional'].map({'Maj2':1, 'Sev':2, 'Min2':3, 'Min1':4, 'Maj1':5, 'Mod':6, 'Typ':7})
test['Functional']=test['Functional'].map({'Maj2':1, 'Sev':2, 'Min2':3, 'Min1':4, 'Maj1':5, 'Mod':6, 'Typ':7})

# %% [markdown]
# #### PavedDrive

# %%
grp=train.groupby('PavedDrive')['SalePrice'].sum().reset_index()
grp=grp.sort_values('PavedDrive')
n=train['PavedDrive'].value_counts().reset_index()
n.columns= ['PavedDrive', 'count']
n=n.sort_values('PavedDrive')
grp =grp.merge(n, on='PavedDrive')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['PavedDrive'], y=grp['Avg'])
# Out:
# <Axes: xlabel='PavedDrive', ylabel='Avg'>

# %% [markdown]
# That would be onehot encoding

# %% [markdown]
# #### SaleType

# %%
grp=train.groupby('SaleType')['SalePrice'].sum().reset_index()
grp=grp.sort_values('SaleType')
n=train['SaleType'].value_counts().reset_index()
n.columns= ['SaleType', 'count']
n=n.sort_values('SaleType')
grp =grp.merge(n, on='SaleType')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['SaleType'], y=grp['Avg'])
# Out:
# <Axes: xlabel='SaleType', ylabel='Avg'>

# %%
train['SaleType']=train['SaleType'].map({'Oth':1, 'ConLD':2, 'ConLw':3, 'COD':4,'WD':5,  'ConLI':6, 'CWD':7, 'Con':8, 'New':9})
test['SaleType']=test['SaleType'].map({'Oth':1, 'ConLD':2, 'ConLw':3, 'COD':4,'WD':5,  'ConLI':6, 'CWD':7, 'Con':8, 'New':9})

# %% [markdown]
# #### SaleCondition

# %%
grp=train.groupby('SaleCondition')['SalePrice'].sum().reset_index()
grp=grp.sort_values('SaleCondition')
n=train['SaleCondition'].value_counts().reset_index()
n.columns= ['SaleCondition', 'count']
n=n.sort_values('SaleCondition')
grp =grp.merge(n, on='SaleCondition')
grp['Avg']=grp['SalePrice']/grp['count']
grp = grp.sort_values('Avg')
sns.barplot(x=grp['SaleCondition'], y=grp['Avg'])
# Out:
# <Axes: xlabel='SaleCondition', ylabel='Avg'>

# %%
train['SaleCondition']=train['SaleCondition'].map({'AdjLand':1, 'Abnorml':2, 'Family':3, 'Alloca':4, 'Normal':5, 'Partial':6})
test['SaleCondition']=test['SaleCondition'].map({'AdjLand':1, 'Abnorml':2, 'Family':3, 'Alloca':4, 'Normal':5, 'Partial':6})

# %%
train = pd.concat([train, pd.get_dummies(train['CentralAir'], prefix='CentralAir', dtype=int)], axis=1)
test = pd.concat([test, pd.get_dummies(test['CentralAir'], prefix='CentralAir', dtype=int)], axis=1)

# %%
train = pd.concat([train, pd.get_dummies(train['PavedDrive'], prefix='PavedDrive', dtype=int)], axis=1)
test = pd.concat([test, pd.get_dummies(test['PavedDrive'], prefix='PavedDrive', dtype=int)], axis=1)

# %%
column = ['CentralAir', 'PavedDrive']
train.drop(columns=column, axis=1, inplace=True)
test.drop(columns=column, axis=1, inplace=True)

# %% [markdown]
# ### MICE for MAR data

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge

imputer = IterativeImputer(estimator = BayesianRidge(), max_iter=10, tol = 1e-3, n_nearest_features=None, initial_strategy='mean',
                          sample_posterior=True, random_state=0, min_value = 0)

imputed_np_train =imputer.fit_transform(train)
train = pd.DataFrame(imputed_np_train, columns=train.columns)

imputed_np_test=imputer.fit_transform(test)
test = pd.DataFrame(imputed_np_test, columns=test.columns)

# %%
train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0        60.0       4.0         65.0   8450.0     2.0    3.0       1.0
# 1        20.0       4.0         80.0   9600.0     2.0    3.0       1.0
# 2        60.0       4.0         68.0  11250.0     2.0    3.0       2.0
# 3        70.0       4.0         60.0   9550.0     2.0    3.0       2.0
# 4        60.0       4.0         84.0  14260.0     2.0    3.0       2.0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0          2.0        2.0        1.0        1.0          17.0         5.0
# 1          2.0        2.0        2.0        1.0          21.0         3.0
# 2          2.0        2.0        1.0        1.0          17.0         5.0
# 3          2.0        2.0        3.0        1.0          18.0         5.0
# 4          2.0        2.0        2.0        1.0          25.0         5.0
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0        20.0       3.0         80.0  11622.0     2.0    3.0       1.0
# 1        20.0       4.0         81.0  14267.0     2.0    3.0       2.0
# 2        60.0       4.0         74.0  13830.0     2.0    3.0       2.0
# 3        60.0       4.0         78.0   9978.0     2.0    3.0       2.0
# 4       120.0       4.0         43.0   5005.0     2.0    3.0       2.0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0          2.0        2.0        1.0        1.0          11.0         3.0
# 1          2.0        2.0        3.0        1.0          11.0         5.0
# 2          2.0        2.0        1.0        1.0          15.0         5.0
# 3          2.0        2.0        1.0        1.0          15.0         5.0
# 4          4.0        2.0        1.0        1.0          23.0         5.0
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train2 = pd.read_csv('train.csv')
test2 = pd.read_csv('test.csv')

# %%
train2['Alley']=train2['Alley'].map({'Grvl':1, 'Pave':2, 'M':3})
test2['Alley']=test2['Alley'].map({'Grvl':1, 'Pave':2, 'M':3})
train2['MasVnrType']=train2['MasVnrType'].map({'BrkCmn':1, 'M':2, 'BrkFace':3, 'Stone':4})
test2['MasVnrType']=test2['MasVnrType'].map({'BrkCmn':1, 'M':2, 'BrkFace':3, 'Stone':4})
train2['BsmtQual']=train2['BsmtQual'].map({'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test2['BsmtQual']=test2['BsmtQual'].map({'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
train2['BsmtCond']=train2['BsmtCond'].map({'Po':1, 'M':2, 'Fa':3, 'TA':4, 'Gd':5})
test2['BsmtCond']=test2['BsmtCond'].map({'Po':1, 'M':2, 'Fa':3, 'TA':4, 'Gd':5})
train2['BsmtExposure']=train2['BsmtExposure'].map({'M':1, 'No':2, 'Mn':3, 'Av':4, 'Gd':5})
test2['BsmtExposure']=test2['BsmtExposure'].map({'M':1, 'No':2, 'Mn':3, 'Av':4, 'Gd':5})
train2['BsmtFinType1']=train2['BsmtFinType1'].map({'M':1, 'Rec':2, 'BLQ':3, 'LwQ':4, 'ALQ':5, 'Unf':6, 'GLQ':7})
test2['BsmtFinType1']=test2['BsmtFinType1'].map({'M':1, 'Rec':2, 'BLQ':3, 'LwQ':4, 'ALQ':5, 'Unf':6, 'GLQ':7})
train2['BsmtFinType2']= train2['BsmtFinType2'].map({'M':1, 'BLQ':2, 'LwQ':3, 'Rec':4, 'GLQ':5, 'Unf':6, 'ALQ':7})
test2['BsmtFinType2']= test2['BsmtFinType2'].map({'M':1, 'BLQ':2, 'LwQ':3, 'Rec':4, 'GLQ':5, 'Unf':6, 'ALQ':7})
train2['Electrical']=train2['Electrical'].map({'Mix':1, 'FuseP':2, 'FuseF':3, 'FuseA':4, 'SBrkr':5})
test2['Electrical']=test2['Electrical'].map({'Mix':1, 'FuseP':2, 'FuseF':3, 'FuseA':4, 'SBrkr':5})
train2['FireplaceQu']=train2['FireplaceQu'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test2['FireplaceQu']=test2['FireplaceQu'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
train2['GarageType']=train2['GarageType'].map({'M':1, 'CarPort':2, 'Detchd':3, '2Types':4, 'Basment':5, 'Attchd':6, 'BuiltIn':7})
test2['GarageType']=test2['GarageType'].map({'M':1, 'CarPort':2, 'Detchd':3, '2Types':4, 'Basment':5, 'Attchd':6, 'BuiltIn':7})
train2['GarageFinish']=train2['GarageFinish'].map({'M':1, 'Unf':2, 'RFn':3, 'Fin':4})
test2['GarageFinish']=test2['GarageFinish'].map({'M':1, 'Unf':2, 'RFn':3, 'Fin':4})
train2['GarageQual']=train2['GarageQual'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test2['GarageQual']=test2['GarageQual'].map({'Po':1,'M':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
train2['GarageCond']=train2['GarageCond'].map({'M':1, 'Po':2, 'Fa':3, 'Ex':4, 'Gd':5, 'TA':6})
test2['GarageCond']=test2['GarageCond'].map({'M':1, 'Po':2, 'Fa':3, 'Ex':4, 'Gd':5, 'TA':6})
train2['PoolQC']=train2['PoolQC'].map({'M':1, 'Gd':2, 'Fa':3, 'Ex':4})
test2['PoolQC']=test2['PoolQC'].map({'M':1, 'Gd':2, 'Fa':3, 'Ex':4})
train2['Fence']=train2['Fence'].map({'MnWw':1, 'GdWo':2, 'MnPrv':3, 'GdPrv':4, 'M':5})
test2['Fence']=test2['Fence'].map({'MnWw':1, 'GdWo':2, 'MnPrv':3, 'GdPrv':4, 'M':5})
train2['MiscFeature']=train2['MiscFeature'].map({'Othr':1, 'Shed':2, 'Gar2':3, 'M':4, 'TenC':5})
test2['MiscFeature']=test2['MiscFeature'].map({'Othr':1, 'Shed':2, 'Gar2':3, 'M':4, 'TenC':5})

# %%
cat = null_columns_train
for col in cat:
    plt.figure(figsize=(20, 8))
    plt.subplot(1, 2, 1)
    sns.histplot(x=train2[col], kde=True)
    plt.title(f'before {col}')


    plt.subplot(1, 2, 2)
    sns.histplot(x=train[col], kde=True)
    plt.title(f'after {col}')

plt.tight_layout()
plt.show()

# %%
test2['MSZoning']=test2['MSZoning'].map({'C (all)':1, 'RM':2, 'RH':3, 'RL':4, 'FV':5})
test2['Utilities']=test2['Utilities'].map({'NoSeWa':1, 'AllPub':2})
#train['Exterior1st']=train['Exterior1st'].map({'BrkComm':1, 'AsphShn':2, 'CBlock':3, 'AsbShng':4, 'MetalSd':5, 'Wd Sdng':6, 'WdShing':7, 'Stucco':8, 'HdBoard':9, 'Plywood':10, 'BrkFace':11, 'VinylSd':12, 'CemntBd':13, 'Stone':14, 'ImStucc':15})
test2['Exterior1st']=test2['Exterior1st'].map({'BrkComm':1, 'AsphShn':2, 'CBlock':3, 'AsbShng':4, 'MetalSd':5, 'Wd Sdng':6, 'WdShing':7, 'Stucco':8, 'HdBoard':9, 'Plywood':10, 'BrkFace':11, 'VinylSd':12, 'CemntBd':13, 'Stone':14, 'ImStucc':15})
#train['Exterior2nd']=train['Exterior2nd'].map({'CBlock':1, 'AsbShng':2, 'Brk Cmn':3, 'AsphShn':4, 'Wd Sdng':5, 'MetalSd':6, 'Stucco':7, 'Stone':8, 'Wd Shng':9, 'HdBoard':10, 'Plywood':11, 'BrkFace':12, 'VinylSd':13, 'CmentBd':14, 'ImStucc':15, 'Other':16})
test2['Exterior2nd']=test2['Exterior2nd'].map({'CBlock':1, 'AsbShng':2, 'Brk Cmn':3, 'AsphShn':4, 'Wd Sdng':5, 'MetalSd':6, 'Stucco':7, 'Stone':8, 'Wd Shng':9, 'HdBoard':10, 'Plywood':11, 'BrkFace':12, 'VinylSd':13, 'CmentBd':14, 'ImStucc':15, 'Other':16})
test2['KitchenQual']=test2['KitchenQual'].map({'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
test2['Functional']=test2['Functional'].map({'Maj2':1, 'Sev':2, 'Min2':3, 'Min1':4, 'Maj1':5, 'Mod':6, 'Typ':7})
test2['SaleType']=test2['SaleType'].map({'Oth':1, 'ConLD':2, 'ConLw':3, 'COD':4,'WD':5,  'ConLI':6, 'CWD':7, 'Con':8, 'New':9})

# %%
cat = null_columns_test
for col in cat:
    plt.figure(figsize=(20, 8))
    plt.subplot(1, 2, 1)
    sns.histplot(x=test2[col], kde=True)
    plt.title(f'before {col}')


    plt.subplot(1, 2, 2)
    sns.histplot(x=test[col], kde=True)
    plt.title(f'after {col}')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\IFAD\AppData\Local\Temp\ipykernel_6864\1303034104.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(20, 8))

# %%
train = train.drop('SalePrice', axis=1)

# %% [markdown]
# # Fixing Outliers

# %%
for col in column_s:
    plt.figure(figsize=(20, 8))
    
    plt.subplot(1,4,1)
    plt.boxplot(train[col])
    plt.title(f"train {col}")
    
    plt.subplot(1,4,2)
    sns.histplot(x=train[col], kde=True)
    plt.title(f"train {col}")
    
    plt.subplot(1,4,3)
    sns.histplot(x=test[col], kde=True)
    plt.title(f"test {col}")
    
    plt.subplot(1,4,4)
    plt.boxplot(test[col])
    plt.title(f"test {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\IFAD\AppData\Local\Temp\ipykernel_6864\759215705.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(20, 8))

# %%
from scipy.stats import shapiro, normaltest
stat, p = shapiro(train['LandContour'])
st, q=normaltest(train['LandContour'])

print(p)
print(q)
# Out:
# 1.9960066337754307e-56
# 5.703479836045032e-181

# %%
for col in column_s:
    iqr = train[col].quantile(0.75)-train[col].quantile(0.25)
    upper = train[col].quantile(0.75)+(1.5*iqr)
    lower = train[col].quantile(0.75)-(1.5*iqr)
    p=len(train[(train[col]>upper) | (train[col]<lower)])
    print(f'{col} {p}')
# Out:
# MSSubClass 103
# LotFrontage 313
# LotArea 241
# OverallQual 25
# OverallCond 182
# YearBuilt 194
# YearRemodAdd 0
# MasVnrArea 96
# BsmtFinSF1 7
# BsmtFinSF2 167
# BsmtUnfSF 29
# TotalBsmtSF 110
# 1stFlrSF 66
# 2ndFlrSF 2
# LowQualFinSF 26
# GrLivArea 79
# BsmtFullBath 1
# BsmtHalfBath 82
# FullBath 9
# HalfBath 0
# BedroomAbvGr 85
# KitchenAbvGr 68
# TotRmsAbvGrd 48
# Fireplaces 5
# GarageYrBlt 176
# GarageCars 86
# GarageArea 130
# WoodDeckSF 32
# OpenPorchSF 77
# EnclosedPorch 208
# 3SsnPorch 24
# ScreenPorch 116
# PoolArea 7
# MiscVal 52
# MoSold 216
# YrSold 0

# %% [markdown]
# #### OverallQual

# %%
sns.boxplot(train['OverallQual'])
# Out:
# <Axes: ylabel='OverallQual'>

# %%
iqr=train['OverallQual'].quantile(0.75)-train['OverallQual'].quantile(0.25)
upper=train['OverallQual'].quantile(0.75)+(1.5*iqr)
lower=train['OverallQual'].quantile(0.25)-(1.5*iqr)
print(upper)
print(lower)
# Out:
# 10.0
# 2.0

# %%
#train.loc[train['OverallCond']>=7.5, 'OverallCond']=7.5
#test.loc[test['OverallCond']>=7.5, 'OverallCond']=7.5

train.loc[train['OverallQual']<=2, 'OverallQual']=2
test.loc[test['OverallQual']<=2, 'OverallQual']=2

# %% [markdown]
# #### BsmtFinSF1

# %%
sns.boxplot(train['BsmtFinSF1'])
# Out:
# <Axes: ylabel='BsmtFinSF1'>

# %%
iqr=train['BsmtFinSF1'].quantile(0.75)-train['BsmtFinSF1'].quantile(0.25)
upper=train['BsmtFinSF1'].quantile(0.75)+(1.5*iqr)
lower=train['BsmtFinSF1'].quantile(0.25)-(1.5*iqr)
print(upper)
print(lower)
# Out:
# 1780.625
# -1068.375

# %%
train.loc[train['BsmtFinSF1']>=1780.625, 'BsmtFinSF1']=1780.625
test.loc[test['BsmtFinSF1']>=1780.625, 'BsmtFinSF1']=1780.625

# %% [markdown]
# #### BsmtUnfSF

# %%
sns.boxplot(train['BsmtUnfSF'])
# Out:
# <Axes: ylabel='BsmtUnfSF'>

# %%
iqr=train['BsmtUnfSF'].quantile(0.75)-train['BsmtUnfSF'].quantile(0.25)
upper=train['BsmtUnfSF'].quantile(0.75)+(1.5*iqr)
lower=train['BsmtUnfSF'].quantile(0.25)-(1.5*iqr)
print(upper)
print(lower)
# Out:
# 1685.5
# -654.5

# %%
train.loc[train['BsmtUnfSF']>=1685.5, 'BsmtUnfSF']=1685.5
test.loc[test['BsmtUnfSF']>=1685.5, 'BsmtUnfSF']=1685.5

# %% [markdown]
# #### 1stFlrSF

# %%
sns.boxplot(train['1stFlrSF'])
# Out:
# <Axes: ylabel='1stFlrSF'>

# %%
iqr=train['1stFlrSF'].quantile(0.75)-train['1stFlrSF'].quantile(0.25)
upper=train['1stFlrSF'].quantile(0.75)+(1.5*iqr)
lower=train['1stFlrSF'].quantile(0.25)-(1.5*iqr)
print(upper)
print(lower)
# Out:
# 2155.125
# 118.125

# %%
train.loc[train['1stFlrSF']>=2155.125, '1stFlrSF']=2155.125
test.loc[test['1stFlrSF']>=2155.125, '1stFlrSF']=2155.125

# %% [markdown]
# #### 2ndFlrSF

# %%
sns.boxplot(train['2ndFlrSF'])
# Out:
# <Axes: ylabel='2ndFlrSF'>

# %%
iqr=train['2ndFlrSF'].quantile(0.75)-train['2ndFlrSF'].quantile(0.25)
upper=train['2ndFlrSF'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 1820.0

# %%
train.loc[train['2ndFlrSF']>=1820, '2ndFlrSF']=1820
test.loc[test['2ndFlrSF']>=1820, '2ndFlrSF']=1820

# %% [markdown]
# #### LowQualFinSF

# %%
sns.boxplot(train['LowQualFinSF'])
# Out:
# <Axes: ylabel='LowQualFinSF'>

# %%
iqr=train['LowQualFinSF'].quantile(0.75)-train['LowQualFinSF'].quantile(0.25)
upper=train['LowQualFinSF'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 0.0

# %%
train.loc[train['LowQualFinSF']>=0, 'LowQualFinSF']=0
test.loc[test['LowQualFinSF']>=0, 'LowQualFinSF']=0

# %% [markdown]
# #### GrLivArea

# %%
sns.boxplot(train['GrLivArea'])
# Out:
# <Axes: ylabel='GrLivArea'>

# %%
iqr=train['GrLivArea'].quantile(0.75)-train['GrLivArea'].quantile(0.25)
upper=train['GrLivArea'].quantile(0.75)+(1.5*iqr)
lower=train['GrLivArea'].quantile(0.25)-(1.5*iqr)
print(upper)
print(lower)
# Out:
# 2747.625
# 158.625

# %%
train.loc[train['GrLivArea']>=2747.625, 'GrLivArea']=2747.625
test.loc[test['GrLivArea']>=2747.625, 'GrLivArea']=2747.625

# %% [markdown]
# #### BsmtFullBath

# %%
sns.boxplot(train['BsmtFullBath'])
# Out:
# <Axes: ylabel='BsmtFullBath'>

# %%
iqr=train['BsmtFullBath'].quantile(0.75)-train['BsmtFullBath'].quantile(0.25)
upper=train['BsmtFullBath'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 2.5

# %%
train.loc[train['BsmtFullBath']>=2.5, 'BsmtFullBath']=2.5
test.loc[test['BsmtFullBath']>=2.5, 'BsmtFullBath']=2.5

# %% [markdown]
# #### BsmtHalfBath

# %%
sns.boxplot(train['BsmtHalfBath'])
# Out:
# <Axes: ylabel='BsmtHalfBath'>

# %%
iqr=train['BsmtHalfBath'].quantile(0.75)-train['BsmtHalfBath'].quantile(0.25)
upper=train['BsmtHalfBath'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 0.0

# %%
train.loc[train['BsmtHalfBath']>=0, 'BsmtHalfBath']=0
test.loc[test['BsmtHalfBath']>=0, 'BsmtHalfBath']=0

# %% [markdown]
# #### BedroomAbvGr

# %%
sns.boxplot(train['BedroomAbvGr'])
# Out:
# <Axes: ylabel='BedroomAbvGr'>

# %%
iqr=train['BedroomAbvGr'].quantile(0.75)-train['BedroomAbvGr'].quantile(0.25)
upper=train['BedroomAbvGr'].quantile(0.75)+(1.5*iqr)
lower=train['BedroomAbvGr'].quantile(0.25)-(1.5*iqr)
print(upper)
print(lower)
# Out:
# 4.5
# 0.5

# %%
train.loc[train['BedroomAbvGr']>=4.5, 'BedroomAbvGr']=4.5
test.loc[test['BedroomAbvGr']>=4.5, 'BedroomAbvGr']=4.5

train.loc[train['BedroomAbvGr']<=0.5, 'BedroomAbvGr']=0.5
test.loc[test['BedroomAbvGr']<=0.5, 'BedroomAbvGr']=0.5

# %% [markdown]
# #### KitchenAbvGr

# %%
sns.boxplot(train['KitchenAbvGr'])
# Out:
# <Axes: ylabel='KitchenAbvGr'>

# %%
iqr=train['KitchenAbvGr'].quantile(0.75)-train['KitchenAbvGr'].quantile(0.25)
upper=train['KitchenAbvGr'].quantile(0.75)+(1.5*iqr)
lower=train['KitchenAbvGr'].quantile(0.25)-(1.5*iqr)
print(upper)
print(lower)
# Out:
# 1.0
# 1.0

# %%
train.loc[train['KitchenAbvGr']>=1, 'KitchenAbvGr']=1
test.loc[test['KitchenAbvGr']>=1, 'KitchenAbvGr']=1

train.loc[train['KitchenAbvGr']<=1, 'KitchenAbvGr']=1
test.loc[test['KitchenAbvGr']<=1, 'KitchenAbvGr']=1

# %% [markdown]
# #### TotRmsAbvGrd

# %%
sns.boxplot(train['TotRmsAbvGrd'])
# Out:
# <Axes: ylabel='TotRmsAbvGrd'>

# %%
iqr=train['TotRmsAbvGrd'].quantile(0.75)-train['TotRmsAbvGrd'].quantile(0.25)
upper=train['TotRmsAbvGrd'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 10.0

# %%
train.loc[train['TotRmsAbvGrd']>=10, 'TotRmsAbvGrd']=10
test.loc[test['TotRmsAbvGrd']>=10, 'TotRmsAbvGrd']=10

# %% [markdown]
# #### Fireplaces

# %%
sns.boxplot(train['Fireplaces'])
# Out:
# <Axes: ylabel='Fireplaces'>

# %%
iqr=train['Fireplaces'].quantile(0.75)-train['Fireplaces'].quantile(0.25)
upper=train['Fireplaces'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 2.5

# %%
train.loc[train['Fireplaces']>=2.5, 'Fireplaces']=2.5
test.loc[test['Fireplaces']>=2.5, 'Fireplaces']=2.5

# %% [markdown]
# #### GarageCars

# %%
sns.boxplot(train['GarageCars'])
# Out:
# <Axes: ylabel='GarageCars'>

# %%
iqr=train['GarageCars'].quantile(0.75)-train['GarageCars'].quantile(0.25)
upper=train['GarageCars'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 3.5

# %%
train.loc[train['GarageCars']>=3.5, 'GarageCars']=3.5
test.loc[test['GarageCars']>=3.5, 'GarageCars']=3.5

# %% [markdown]
# #### WoodDeckSF

# %%
sns.boxplot(train['WoodDeckSF'])
# Out:
# <Axes: ylabel='WoodDeckSF'>

# %%
iqr=train['WoodDeckSF'].quantile(0.75)-train['WoodDeckSF'].quantile(0.25)
upper=train['WoodDeckSF'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 420.0

# %%
train.loc[train['WoodDeckSF']>=420, 'WoodDeckSF']=420
test.loc[test['WoodDeckSF']>=420, 'WoodDeckSF']=420

# %% [markdown]
# #### OpenPorchSF

# %%
sns.boxplot(train['OpenPorchSF'])
# Out:
# <Axes: ylabel='OpenPorchSF'>

# %%
iqr=train['OpenPorchSF'].quantile(0.75)-train['OpenPorchSF'].quantile(0.25)
upper=train['OpenPorchSF'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 170.0

# %%
train.loc[train['OpenPorchSF']>=170, 'OpenPorchSF']=170
test.loc[test['OpenPorchSF']>=170, 'OpenPorchSF']=170

# %% [markdown]
# #### 3SsnPorch

# %%
sns.boxplot(train['3SsnPorch'])
# Out:
# <Axes: ylabel='3SsnPorch'>

# %%
iqr=train['3SsnPorch'].quantile(0.75)-train['3SsnPorch'].quantile(0.25)
upper=train['3SsnPorch'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 0.0

# %%
train.loc[train['3SsnPorch']>=0, '3SsnPorch']=0
test.loc[test['3SsnPorch']>=0, '3SsnPorch']=0

# %% [markdown]
# #### PoolArea

# %%
sns.boxplot(train['PoolArea'])
# Out:
# <Axes: ylabel='PoolArea'>

# %%
iqr=train['PoolArea'].quantile(0.75)-train['PoolArea'].quantile(0.25)
upper=train['PoolArea'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 0.0

# %%
train.loc[train['PoolArea']>=0, 'PoolArea']=0
test.loc[test['PoolArea']>=0, 'PoolArea']=0

# %% [markdown]
# #### MiscVal

# %%
sns.boxplot(train['MiscVal'])
# Out:
# <Axes: ylabel='MiscVal'>

# %%
iqr=train['MiscVal'].quantile(0.75)-train['MiscVal'].quantile(0.25)
upper=train['MiscVal'].quantile(0.75)+(1.5*iqr)

print(upper)
# Out:
# 0.0

# %%
train.loc[train['MiscVal']>=0, 'MiscVal']=0
test.loc[test['MiscVal']>=0, 'MiscVal']=0

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(train)
x=scaler.transform(train)
test_scaled=scaler.transform(test)

# %%
x=pd.DataFrame(x, columns=train.columns)
test_scaled=pd.DataFrame(test_scaled, columns=test.columns)

# %%
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea    Street     Alley  LotShape  \
# 0    0.073375  0.359044    -0.312932 -0.207142  0.064238  0.244717 -0.657040
# 1   -0.872563  0.359044     0.022564 -0.091886  0.064238  0.244717 -0.657040
# 2    0.073375  0.359044    -0.245832  0.073480  0.064238  0.244717  0.872909
# 3    0.309859  0.359044    -0.424763 -0.096897  0.064238  0.244717  0.872909
# 4    0.073375  0.359044     0.112030  0.375148  0.064238  0.244717  0.872909
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0    -0.111168    0.02618  -0.561478  -0.225716      0.626747    0.212875
# 1    -0.111168    0.02618   0.291548  -0.225716      1.249443   -1.779413
# 2    -0.111168    0.02618  -0.561478  -0.225716      0.626747    0.212875
# 3    -0.111168    0.02618   1.144574  -0.225716      0.782421    0.212875
# 4    -0.111168    0.02618   0.291548  -0.225716      1.872139    0.212875
#
# ...

# %%
test_scaled.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea    Street     Alley  LotShape  \
# 0   -0.872563 -0.898040     0.022564  0.110763  0.064238  0.244717 -0.657040
# 1   -0.872563  0.359044     0.044931  0.375850  0.064238  0.244717  0.872909
# 2    0.073375  0.359044    -0.111634  0.332053  0.064238  0.244717  0.872909
# 3    0.073375  0.359044    -0.022169 -0.054002  0.064238  0.244717  0.872909
# 4    1.492282  0.359044    -0.804992 -0.552407  0.064238  0.244717  0.872909
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0    -0.111168    0.02618  -0.561478  -0.225716     -0.307296   -1.779413
# 1    -0.111168    0.02618   1.144574  -0.225716     -0.307296    0.212875
# 2    -0.111168    0.02618  -0.561478  -0.225716      0.315400    0.212875
# 3    -0.111168    0.02618  -0.561478  -0.225716      0.315400    0.212875
# 4     4.335534    0.02618  -0.561478  -0.225716      1.560791    0.212875
#
# ...

# %% [markdown]
# # Model Train & Evaluation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kfold=KFold(n_splits=10, shuffle=True, random_state=0)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer

# %% [markdown]
# #### LinearRegression

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
scoring_mae=make_scorer(mean_absolute_error, greater_is_better=False)
score_mae = cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mae)
print('Mean MAE:' ,-np.mean(score_mae))

scoring_mse=make_scorer(mean_squared_error, greater_is_better=False)
score_mse=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mse)
print('Mean MSE:', -np.mean(score_mse))

print('Mean RMSE:', np.sqrt(-np.mean(score_mse)))

score_r2=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring='r2')
print('Mean R2:', np.mean(score_r2))

r2=np.mean(score_r2)
adj_r2=1-(((1-r2)*(1460-1))/(1460-1-82))
print('Adjustes R2:', adj_r2)
# Out:
# Mean MAE: 20109.32186102145
# Mean MSE: 1223355563.9470425
# Mean RMSE: 34976.50016721288
# Mean R2: 0.809330196841269
# Adjustes R2: 0.7979758585268056

# %% [markdown]
# #### RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
clf=RandomForestRegressor()
scoring_mae=make_scorer(mean_absolute_error, greater_is_better=False)
score_mae = cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mae)
print('Mean MAE:' ,-np.mean(score_mae))

scoring_mse=make_scorer(mean_squared_error, greater_is_better=False)
score_mse=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mse)
print('Mean MSE:', -np.mean(score_mse))

print('Mean RMSE:', np.sqrt(-np.mean(score_mse)))

score_r2=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring='r2')
print('Mean R2:', np.mean(score_r2))

r2=np.mean(score_r2)
adj_r2=1-(((1-r2)*(1460-1))/(1460-1-82))
print('Adjustes R2:', adj_r2)
# Out:
# Mean MAE: 16789.119924657534
# Mean MSE: 780631590.6729023
# Mean RMSE: 27939.78508637642
# Mean R2: 0.8759805607776331
# Adjustes R2: 0.8685952346946744

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
clf=GradientBoostingRegressor()
scoring_mae=make_scorer(mean_absolute_error, greater_is_better=False)
score_mae = cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mae)
print('Mean MAE:' ,-np.mean(score_mae))

scoring_mse=make_scorer(mean_squared_error, greater_is_better=False)
score_mse=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mse)
print('Mean MSE:', -np.mean(score_mse))

print('Mean RMSE:', np.sqrt(-np.mean(score_mse)))

score_r2=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring='r2')
print('Mean R2:', np.mean(score_r2))

r2=np.mean(score_r2)
adj_r2=1-(((1-r2)*(1460-1))/(1460-1-82))
print('Adjustes R2:', adj_r2)
# Out:
# Mean MAE: 15590.435884203293
# Mean MSE: 660169232.3240411
# Mean RMSE: 25693.758625861672
# Mean R2: 0.8958341870494531
# Adjustes R2: 0.889631139364671

# %% [markdown]
# #### XGB Regressor

# %%
from xgboost import XGBRegressor
clf=XGBRegressor()
scoring_mae=make_scorer(mean_absolute_error, greater_is_better=False)
score_mae = cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mae)
print('Mean MAE:' ,-np.mean(score_mae))

scoring_mse=make_scorer(mean_squared_error, greater_is_better=False)
score_mse=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mse)
print('Mean MSE:', -np.mean(score_mse))

print('Mean RMSE:', np.sqrt(-np.mean(score_mse)))

score_r2=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring='r2')
print('Mean R2:', np.mean(score_r2))

r2=np.mean(score_r2)
adj_r2=1-(((1-r2)*(1460-1))/(1460-1-82))
print('Adjustes R2:', adj_r2)
# Out:
# G:\Anaconda\Lib\site-packages\xgboost\compat.py:105: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Mean MAE: 16706.9095703125
# Mean MSE: 773317244.8
# Mean RMSE: 27808.58221484871
# Mean R2: 0.8782317996025085
# Adjustes R2: 0.8709805342193608

# %% [markdown]
# #### LightGBM Regressor

# %%
from lightgbm import LGBMRegressor
clf=LGBMRegressor(verbose=-1)
scoring_mae=make_scorer(mean_absolute_error, greater_is_better=False)
score_mae = cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mae)
print('Mean MAE:' ,-np.mean(score_mae))

scoring_mse=make_scorer(mean_squared_error, greater_is_better=False)
score_mse=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mse)
print('Mean MSE:', -np.mean(score_mse))

print('Mean RMSE:', np.sqrt(-np.mean(score_mse)))

score_r2=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring='r2')
print('Mean R2:', np.mean(score_r2))

r2=np.mean(score_r2)
adj_r2=1-(((1-r2)*(1460-1))/(1460-1-82))
print('Adjustes R2:', adj_r2)
# Out:
# Mean MAE: 16058.693577197186
# Mean MSE: 808947931.7636616
# Mean RMSE: 28442.00998107661
# Mean R2: 0.8731006786105677
# Adjustes R2: 0.8655438562765565

# %% [markdown]
# #### CatBoost Regressor

# %%
from catboost import CatBoostRegressor
clf=CatBoostRegressor(verbose=False)
scoring_mae=make_scorer(mean_absolute_error, greater_is_better=False)
score_mae = cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mae)
print('Mean MAE:' ,-np.mean(score_mae))

scoring_mse=make_scorer(mean_squared_error, greater_is_better=False)
score_mse=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mse)
print('Mean MSE:', -np.mean(score_mse))

print('Mean RMSE:', np.sqrt(-np.mean(score_mse)))

score_r2=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring='r2')
print('Mean R2:', np.mean(score_r2))

r2=np.mean(score_r2)
adj_r2=1-(((1-r2)*(1460-1))/(1460-1-82))
print('Adjustes R2:', adj_r2)
# Out:
# Mean MAE: 14196.949109058685
# Mean MSE: 610620691.2772806
# Mean RMSE: 24710.740403259482
# Mean R2: 0.9044628498601449
# Adjustes R2: 0.8987736368525427

# %% [markdown]
# #### MLP Regresssor

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)
from sklearn.neural_network import MLPRegressor
clf=MLPRegressor(verbose = False)
scoring_mae=make_scorer(mean_absolute_error, greater_is_better=False)
score_mae = cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mae)
print('Mean MAE:' ,-np.mean(score_mae))

scoring_mse=make_scorer(mean_squared_error, greater_is_better=False)
score_mse=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring=scoring_mse)
print('Mean MSE:', -np.mean(score_mse))

print('Mean RMSE:', np.sqrt(-np.mean(score_mse)))

score_r2=cross_val_score(clf, x, train_y, cv=kfold, n_jobs=1, scoring='r2')
print('Mean R2:', np.mean(score_r2))

r2=np.mean(score_r2)
adj_r2=1-(((1-r2)*(1460-1))/(1460-1-82))
print('Adjustes R2:', adj_r2)
# Out:
# Mean MAE: 176410.51854139
# Mean MSE: 37052161833.63602
# Mean RMSE: 192489.38109318138
# Mean R2: -5.029722684213711
# Adjustes R2: -5.3887911374493855

# %% [markdown]
# # Submission

# %% [markdown]
# #### Linear Regression

# %%
clf = LinearRegression()
clf.fit(x, train_y)
pred=clf.predict(test_scaled)
sub=pd.DataFrame({'Id':ID, 'SalePrice':pred})
sub.to_csv('aiMH_fxOL_lr.csv')
